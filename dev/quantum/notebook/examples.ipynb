# %%
import tensorcircuit as tc

# %%
c = tc.Circuit(2)
c.h(0)
c.cx(0, 1)
c.draw(idle_wires=False)
# Out:
#      ┌───┐
# q_0: ┤ H ├──■──
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├
#           └───┘

# %%
from tensorcircuit.cloud import apis
apis.list_devices()
# Out:
# [tencent::tianxuan_s1,
#  tencent::tianji_m2v16s1,
#  tencent::tianji_m2,
#  tencent::tianxuan_s2,
#  tencent::tianji_m1v15s2,
#  tencent::tianji_m1,
#  tencent::simulator:tc,
#  tencent::tianji_m2v14s2,
#  tencent::tianji_m2v15s3,
#  tencent::tianji_m1v15s1,
#  tencent::tianji_m2v14s4,
#  tencent::tianxuan_s2v20s2,
#  tencent::tianxuan_s2v20s1,
#  tencent::tianji_m1v15s3,
#  tencent::tianji_m1v15s4,
#  tencent::tianji_s2,
#  tencent::tianji_s2v6,
#  tencent::tianji_s2v7]

# %%
t = apis.submit_task(
    device="simulator:tc",
    circuit=c,
    shots=1024
)
# Out:
# invalid device
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 t = apis.submit_task(
#       2     device="simulator:tc",
#       3     circuit=c,
#       4     shots=1024
#       5 )
#
# File ~/Code/scow-quantum-env/.venv/lib/python3.8/site-packages/tensorcircuit/cloud/apis.py:454, in submit_task(provider, device, token, **task_kws)
#     452     token = device.get_token()  # type: ignore
#     453 if provider.name == "tencent":  # type: ignore
# --> 454     return tencent.submit_task(device, token, **task_kws)  # type: ignore
#     455 elif provider.name == "local":  # type: ignore
#     456     return local.submit_task(device, token, **task_kws)  # type: ignore
#
# File ~/Code/scow-quantum-env/.venv/lib/python3.8/site-packages/tensorcircuit/utils.py:155, in arg_alias.<locals>.wrapper(*args, **kws)
#     153             kws[k] = kws[v]
# ...
